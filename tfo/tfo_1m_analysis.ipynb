# %% [markdown]
# # Analysis of pathspider tfo data
#
# This notebook takes an fjson file from `pathspider tfo` and analyzes it for TFO support as well as apparent TFO connection dependency.
#
# First, needful things:

# %%
import json
import pandas as pd
import matplotlib as plt

# %matplotlib inline

def gen_fjson(filename):
    """
    Iterate over objects in an FJSON file.
    """
    with open(filename) as f:
        for line in f:
            try:
                yield json.loads(line)
            except:
                pass

def rejoin_tfo_df(tfo_rdf, config_column='config'):
    tfo_df = tfo_rdf.loc[:,[config_column,'connstate','dip','host','rank',
                            'fwd_rst','rev_rst','tfo_seq','tfo_ack','tfo_dlen',
                            'tfo_synclen','tfo_synkind','tfo_ackclen','tfo_ackkind']]

    tfo_0df = tfo_df[tfo_df[config_column] == 0]
    tfo_0df.index = tfo_0df.dip
    del(tfo_0df[config_column])
    del(tfo_0df['dip'])
    del(tfo_0df['tfo_seq'])
    del(tfo_0df['tfo_ack'])
    del(tfo_0df['tfo_dlen'])
    del(tfo_0df['tfo_synclen'])
    del(tfo_0df['tfo_synkind'])
    del(tfo_0df['tfo_ackclen'])
    del(tfo_0df['tfo_ackkind'])
    tfo_0df.columns = ['conn_t0','host','rank','fwd_rst_t0','rev_rst_t0']

    tfo_1df = tfo_df[tfo_df[config_column] == 1]
    tfo_1df.index = tfo_1df.dip
    del(tfo_1df[config_column])
    del(tfo_1df['dip'])
    del(tfo_1df['host'])
    del(tfo_1df['rank'])
    tfo_1df.columns = ['conn_t1','fwd_rst_t1','rev_rst_t1','tfo_seq','tfo_ack','tfo_dlen',
                       'tfo_synclen','tfo_synkind','tfo_ackclen','tfo_ackkind']

    tfo_jdf = tfo_0df.join(tfo_1df, how="inner")
    tfo_xdf = tfo_0df.loc[tfo_0df.index.difference(tfo_1df.index)]
    
    return(tfo_jdf, tfo_xdf)
            
import requests
import ipaddress

def canid_prefix_asn(addr):
    res = requests.get("http://localhost:8081/prefix.json?addr="+str(addr))
    j = res.json()
    return {'addr': addr,
            'prefix': j['Prefix'],
            'asn': j['ASN'] }
            

def ripestat_prefix_asn(addr):
    res = requests.get("https://stat.ripe.net/data/prefix-overview/data.json?resource="+str(addr))
    data = res.json()['data']
    prefix = None
    asn = None
    try:
        prefix = data['resource']
        asn = data['asns'][0]['asn']
    except KeyError:
        pass
    return {'addr':   addr,
            'prefix': prefix, 
            'asn':    asn}

def prefix_asn_df(df, prefix_cache):
    
    rows = []
    
    for addr in df.index.values:
        
        naddr = ipaddress.ip_network(addr)
        row = None
        
        # check prefix cache
        for pfx in prefix_cache:
            if pfx.overlaps(naddr):
                # cache hit, exit
                row = prefix_cache[pfx].copy()
                row['addr'] = addr
                #print("cached:   "+repr(row))

        # or go to a local canid cache of ripestat
        if not row:
            row = canid_prefix_asn(addr)
            #print("ripestat: "+repr(row))
            prefix_cache[ipaddress.ip_network(row['prefix'])] = row
        
        rows.append(row)
    
    # now augment the input frame
    odf = pd.DataFrame(rows)
    odf.index = odf['addr']
    del(odf['addr'])
    return df.join(odf)

def select_ip4(df):
    return df.loc[pd.Index((s for s in df.index.values if ':' not in s))]

def select_ip6(df):
    return df.loc[pd.Index((s for s in df.index.values if ':'     in s))]

# %% [markdown]
# Load the data into a Pandas dataframe, then select interesting columns, split based on TFO state, and join on destination address.

# %%
#resolute_rdf = pd.DataFrame(gen_fjson("tfo-full-resolute-20170116.ndjson"))

# %%
#%time (resolute_jdf, resolute_xdf) = rejoin_tfo_df(pd.DataFrame(resolute_rdf))
# Out:
# CPU times: user 7.8 s, sys: 497 ms, total: 8.3 s
# Wall time: 8.3 s

# %%
# Merge two runs, only add missing rows from second
#%time (tfo_a_jdf, tfo_a_xdf) = rejoin_tfo_df(pd.DataFrame(gen_fjson("1m-run4.fjson")))
#%time (tfo_b_jdf, tfo_b_xdf) = rejoin_tfo_df(pd.DataFrame(gen_fjson("1m-run4b.fjson")))

#tfo_jdf = tfo_a_jdf.append(tfo_b_jdf).reset_index().drop_duplicates(subset='dip', keep='first').set_index('dip')
#tfo_xdf = tfo_a_xdf.append(tfo_b_xdf).reset_index().drop_duplicates(subset='dip', keep='first').set_index('dip')

#%time (tfo5_jdf, tfo5_xdf) = rejoin_tfo_df(pd.DataFrame(gen_fjson("1m-run5.fjson")))

# %time (tfo6_jdf, tfo6_xdf) = rejoin_tfo_df(pd.DataFrame(gen_fjson("1m-run6.fjson")),config_column='tfostate')

# %time (resolute_jdf, resolute_xdf) = rejoin_tfo_df(pd.DataFrame(gen_fjson("tfo-full-resolute-20170116.ndjson")))
# Out:
# CPU times: user 39 s, sys: 2.43 s, total: 41.5 s
# Wall time: 41.6 s

# %% [markdown]
# Now run the joint data frames through a sieve to classify them as follows:
#
# - TFO works: TFO cookie was received, SYN-ACK ackonwledges data on SYN.
# - TFO data not acked: TFO cookie received, SYN-ACK acknowledges SYN only.
# - TFO data failure: TFO cookie received, no ACK (or RST) of SYN with data.
# - TFO not negotiated: TFO cookie not received, but no TFO-linked connection impairment.
# - TFO connection failure: Presence of TFO option causes connection failure (RST or drop).
# - Connection failure: Neither vanilla TCP nor TFO connection attempt succeeded.

# %%
def tfo_sieve(tfo_jdf, tfo_xdf, prefix_cache):
    # Cookie available on SYN, but not ACK
    tfo_rscookie = tfo_jdf[(tfo_jdf['tfo_synclen'] > 0) & (tfo_jdf['tfo_ackclen'] == 0)]
    
    # Cookie available on ACK, but not SYN (probably retry 254)
    tfo_racookie = tfo_jdf[(tfo_jdf['tfo_synclen'] == 0) & (tfo_jdf['tfo_ackclen'] > 0)]

    # Cookie available on ACK, but not SYN (probably retry 254)
    tfo_rascookie = tfo_jdf[(tfo_jdf['tfo_synclen'] > 0) & (tfo_jdf['tfo_ackclen'] > 0)]

    # Add ASN information to cookie table, we'll use it later
    tfo_cookie = prefix_asn_df(tfo_rscookie.append(tfo_racookie).append(tfo_rascookie), prefix_cache)

    # (special cases... SYN cookie, but not eight bytes long)
    tfo_oddcookie = tfo_cookie[(tfo_cookie['tfo_synclen'] > 0) & (tfo_cookie['tfo_synclen'] != 8)]

    # (special cases... ACK cookie of kind 254: retry)
    tfo_expcookie = tfo_cookie[(tfo_cookie['tfo_ackclen'] > 0) & (tfo_cookie['tfo_ackkind'] == 254)]

    # (special cases... ACK cookie even with SYN cookie)
    tfo_twocookie = tfo_cookie[(tfo_cookie['tfo_synclen'] > 0) & (tfo_cookie['tfo_ackclen'] > 0)]
    
    # TFO works: data sent and ACKed
    tfo_works = tfo_cookie[((tfo_cookie['tfo_ack'] - tfo_cookie['tfo_seq'] - 1) == tfo_cookie['tfo_dlen'])]

    # TFO data not acked: data sent, but ACK only ACKs SYN
    tfo_dna = tfo_cookie[((tfo_cookie['tfo_ack'] - tfo_cookie['tfo_seq'] - 1) == 0)]

    # TFO data failed: data seen, but no ACK seen
    tfo_dfail = tfo_cookie[tfo_cookie['tfo_ack'] == 0]

    # No cookie available
    tfo_nocookie = tfo_jdf[tfo_jdf['tfo_synclen'] == 0]

    # TFO connection failures (where TFO attempted)
    tfo_cfail = tfo_nocookie[~tfo_nocookie['conn_t1']]

    # TFO not negotiated
    tfo_nope = tfo_nocookie[tfo_nocookie['conn_t1']]

    # Complete connection failures
    total_cfail = tfo_xdf[~tfo_xdf['conn_t0']]

    # TFO connection failures (either TFO not attempted or not seen)
    xtfo_cfail = tfo_xdf[tfo_xdf['conn_t0']]
    
    # summarize
    ct_total = len(tfo_jdf) + len(tfo_xdf)
    ct_totalfail = len(total_cfail)
    ct_tfocfail = len(tfo_cfail) + len(xtfo_cfail)
    ct_tfonope = len(tfo_nope)

    ct_tfodfail = len(tfo_dfail)
    ct_tfodna = len(tfo_dna)
    ct_tfoworks = len(tfo_works)
    ct_tfonego = len(tfo_cookie)

    ct_oddcookie = len(tfo_oddcookie)
    ct_expcookie = len(tfo_expcookie)
    ct_twocookie = len(tfo_twocookie)

    ct_tfogoog = len(tfo_cookie[tfo_cookie['asn'] == 15169])
    ct_tfongoog = len(tfo_cookie[tfo_cookie['asn'] != 15169])

    print("Of %6u tested IP addresses:" % (ct_total,))
    print("   %6u (%6.3f%%) completely failed to connect." % (ct_totalfail, 100 * ct_totalfail / ct_total))
    print("   %6u (%6.3f%%) may have TFO-dependent failure." % (ct_tfocfail, 100 * ct_tfocfail / ct_total))
    print("   %6u (%6.3f%%) did not negotiate TFO." % (ct_tfonope, 100 * ct_tfonope / ct_total))
    print("   %6u (%6.3f%%) negotiated TFO, of which:" % (ct_tfonego, 100 * ct_tfonego / ct_total))
    print(" - - - - - - - -")
    print("   %6u (%6.3f%% / %6.3f%%) responded with a type-254 cookie" % 
                  (ct_expcookie, 100 * ct_expcookie / ct_tfonego, 100 * ct_expcookie / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) responded with a non-8-byte cookie" % 
                  (ct_oddcookie, 100 * ct_oddcookie / ct_tfonego, 100 * ct_oddcookie / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) properly ACKed data on SYN" % 
                  (ct_tfoworks, 100 * ct_tfoworks / ct_tfonego, 100 * ct_tfoworks / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) returned a cookie while ACKing data on SYN" % 
                  (ct_twocookie, 100 * ct_twocookie / ct_tfonego, 100 * ct_twocookie / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) did not ACK data on SYN" % 
                  (ct_tfodna, 100 * ct_tfodna / ct_tfonego, 100 * ct_tfodna / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) failed with data on SYN" % 
                  (ct_tfodfail, 100 * ct_tfodfail / ct_tfonego, 100 * ct_tfodfail / ct_total))
    print(" - - - - - - - -")
    print("   %6u (%6.3f%% / %6.3f%%) are Google properties" %
                  (ct_tfogoog, 100 * ct_tfogoog / ct_tfonego, 100 * ct_tfogoog / ct_total))
    print("   %6u (%6.3f%% / %6.3f%%) are not Google properties" %
                  (ct_tfongoog, 100 * ct_tfongoog / ct_tfonego, 100 * ct_tfongoog / ct_total))

    return {'cookie': tfo_cookie,
            'oddcookie': tfo_oddcookie,
            'expcookie': tfo_expcookie,
            'twocookie': tfo_twocookie,
            'works': tfo_works,
            'dna': tfo_dna,
            'dfail': tfo_dfail,
            'nope': tfo_nope,
            'tcfail': total_cfail,
            'xcfail': xtfo_cfail}

# %%
prefix_cache = {}
print('All addresses:')
sieve6all = tfo_sieve(resolute_jdf, resolute_xdf, prefix_cache)
print('IPv4 only:')
sieve6v4 = tfo_sieve(select_ip4(resolute_jdf), select_ip4(resolute_xdf), prefix_cache)
print('IPv6 only:')
sieve6v6 = tfo_sieve(select_ip6(resolute_jdf), select_ip6(resolute_xdf), prefix_cache)
# Out:
# All addresses:
# Of 939680 tested IP addresses:
#     29839 ( 3.175%) completely failed to connect.
#       177 ( 0.019%) may have TFO-dependent failure.
#    908464 (96.678%) did not negotiate TFO.
#       866 ( 0.092%) negotiated TFO, of which:
#  - - - - - - - -
#        31 ( 3.580% /  0.003%) responded with a type-254 cookie
#        12 ( 1.386% /  0.001%) responded with a non-8-byte cookie
#       830 (95.843% /  0.088%) properly ACKed data on SYN
#        33 ( 3.811% /  0.004%) returned a cookie while ACKing data on SYN
#        68 ( 7.852% /  0.007%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#       690 (79.677% /  0.073%) are Google properties
#       176 (20.323% /  0.019%) are not Google properties
# IPv4 only:
# Of 843966 tested IP addresses:
#     25333 ( 3.002%) completely failed to connect.
#       168 ( 0.020%) may have TFO-dependent failure.
#    817479 (96.862%) did not negotiate TFO.
#       809 ( 0.096%) negotiated TFO, of which:
#  - - - - - - - -
#        29 ( 3.585% /  0.003%) responded with a type-254 cookie
#        12 ( 1.483% /  0.001%) responded with a non-8-byte cookie
#       773 (95.550% /  0.092%) properly ACKed data on SYN
#        32 ( 3.956% /  0.004%) returned a cookie while ACKing data on SYN
#        66 ( 8.158% /  0.008%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#       651 (80.470% /  0.077%) are Google properties
#       158 (19.530% /  0.019%) are not Google properties
# IPv6 only:
# Of  95714 tested IP addresses:
#      4506 ( 4.708%) completely failed to connect.
#         9 ( 0.009%) may have TFO-dependent failure.
#     90985 (95.059%) did not negotiate TFO.
#        57 ( 0.060%) negotiated TFO, of which:
#  - - - - - - - -
#         2 ( 3.509% /  0.002%) responded with a type-254 cookie
#         0 ( 0.000% /  0.000%) responded with a non-8-byte cookie
#        57 (100.000% /  0.060%) properly ACKed data on SYN
#         1 ( 1.754% /  0.001%) returned a cookie while ACKing data on SYN
#         2 ( 3.509% /  0.002%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#        39 (68.421% /  0.041%) are Google properties
#        18 (31.579% /  0.019%) are not Google properties

# %%
prefix_cache = {}
print('All addresses:')
sieve6all = tfo_sieve(tfo6_jdf, tfo6_xdf, prefix_cache)
print('IPv4 only:')
sieve6v4 = tfo_sieve(select_ip4(tfo6_jdf), select_ip4(tfo6_xdf), prefix_cache)
print('IPv6 only:')
sieve6v6 = tfo_sieve(select_ip6(tfo6_jdf), select_ip6(tfo6_xdf), prefix_cache)
# Out:
# All addresses:
# Of 673230 tested IP addresses:
#     18777 ( 2.789%) completely failed to connect.
#       211 ( 0.031%) may have TFO-dependent failure.
#    653681 (97.096%) did not negotiate TFO.
#       578 ( 0.086%) negotiated TFO, of which:
#  - - - - - - - -
#        15 ( 2.595% /  0.002%) responded with a type-254 cookie
#        11 ( 1.903% /  0.002%) responded with a non-8-byte cookie
#       563 (97.405% /  0.084%) properly ACKed data on SYN
#        16 ( 2.768% /  0.002%) returned a cookie while ACKing data on SYN
#        32 ( 5.536% /  0.005%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#       485 (83.910% /  0.072%) are Google properties
#        93 (16.090% /  0.014%) are not Google properties
# IPv4 only:
# Of 620560 tested IP addresses:
#     15818 ( 2.549%) completely failed to connect.
#       208 ( 0.034%) may have TFO-dependent failure.
#    604023 (97.335%) did not negotiate TFO.
#       528 ( 0.085%) negotiated TFO, of which:
#  - - - - - - - -
#        15 ( 2.841% /  0.002%) responded with a type-254 cookie
#        11 ( 2.083% /  0.002%) responded with a non-8-byte cookie
#       513 (97.159% /  0.083%) properly ACKed data on SYN
#        14 ( 2.652% /  0.002%) returned a cookie while ACKing data on SYN
#        32 ( 6.061% /  0.005%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#       441 (83.523% /  0.071%) are Google properties
#        87 (16.477% /  0.014%) are not Google properties
# IPv6 only:
# Of  52670 tested IP addresses:
#      2959 ( 5.618%) completely failed to connect.
#         3 ( 0.006%) may have TFO-dependent failure.
#     49658 (94.281%) did not negotiate TFO.
#        50 ( 0.095%) negotiated TFO, of which:
#  - - - - - - - -
#         0 ( 0.000% /  0.000%) responded with a type-254 cookie
#         0 ( 0.000% /  0.000%) responded with a non-8-byte cookie
#        50 (100.000% /  0.095%) properly ACKed data on SYN
#         2 ( 4.000% /  0.004%) returned a cookie while ACKing data on SYN
#         0 ( 0.000% /  0.000%) did not ACK data on SYN
#         0 ( 0.000% /  0.000%) failed with data on SYN
#  - - - - - - - -
#        44 (88.000% /  0.084%) are Google properties
#         6 (12.000% /  0.011%) are not Google properties

# %% [markdown]
# Dump all TFO-supporting websites, and apparently-TFO-connection-failing websites, to CSV, so we can check them from multiple vantage points.

# %%
with open("tfo_cookie7.csv", "w") as file:
    tfo_cookie_csv = sieve6all['cookie'].copy()
    tfo_cookie_csv['port'] = 80
    file.write(tfo_cookie_csv.loc[:,["port","host","rank"]].to_csv(header=False))

with open("tfo_cfail7.csv", "w") as file:
    tfo_cfail_csv = sieve6all['tcfail'].copy()
    tfo_cfail_csv['port'] = 80
    file.write(tfo_cfail_csv.loc[:,["port","host","rank"]].to_csv(header=False))
    xtfo_cfail_csv = sieve6all['xcfail'].copy()
    xtfo_cfail_csv['port'] = 80
    file.write(xtfo_cfail_csv.loc[:,["port","host","rank"]].to_csv(header=False))

# %% [markdown]
# What about odd cookies?

# %%
sieve6all['oddcookie']
# Out:
#                 conn_t0                    host    rank fwd_rst_t0 rev_rst_t0  \
# dip
# 195.53.217.36      True               mapfre.es   53336      False      False
# 195.25.232.194     True                macif.fr   62072      False      False
# 57.74.24.130       True                 weg.net  144757      False      False
# 195.235.248.195    True     fundacionmapfre.org  158909      False      False
# 212.170.33.244     True                verti.es  164578      False      False
# 195.53.217.193     True              mapfre.com  180053      False       True
# 195.235.248.34     True  jubilacionypension.com  279894      False      False
# 195.235.248.46     True    mapfretecuidamos.com  288347      False       True
# 195.53.217.43      True              mapfre.net  609528      False      False
# 212.170.33.198     True     mapfre-warranty.com  713074      False      False
# 195.235.248.60     True     generacionyoung.com  769812      False      False
# 195.235.248.190    True         mapfregrupo.com  884094      False      False
#
#                 conn_t1 fwd_rst_t1 rev_rst_t1       tfo_seq       tfo_ack  \
# dip
# 195.53.217.36      True       True      False  4.212357e+09  4.212357e+09
# 195.25.232.194     True       True      False  5.287686e+08  5.287686e+08
# 57.74.24.130       True       True      False  3.856047e+09  3.856047e+09
# 195.235.248.195    True       True      False  8.679613e+08  8.679613e+08
# 212.170.33.244     True       True      False  1.104188e+09  1.104188e+09
# 195.53.217.193     True       True      False  5.986354e+08  5.986354e+08
# 195.235.248.34     True       True      False  2.507622e+09  2.507622e+09
# 195.235.248.46     True       True      False  1.324109e+09  1.324109e+09
# 195.53.217.43      True       True      False  1.829123e+09  1.829123e+09
# 212.170.33.198     True       True      False  3.608641e+09  3.608641e+09
# 195.235.248.60     True       True      False  3.510089e+09  3.510089e+09
# 195.235.248.190    True       True      False  1.635639e+09  1.635639e+09
#
#                  tfo_dlen  tfo_synclen  tfo_synkind  tfo_ackclen  tfo_ackkind  \
# dip
# 195.53.217.36        35.0          6.0         34.0          6.0         34.0
# 195.25.232.194       34.0          6.0         34.0          6.0         34.0
# 57.74.24.130         33.0          6.0         34.0          6.0         34.0
# 195.235.248.195      45.0          6.0         34.0          6.0         34.0
# 212.170.33.244       34.0          6.0         34.0          6.0         34.0
# 195.53.217.193       36.0          6.0         34.0          6.0         34.0
# 195.235.248.34       48.0          6.0         34.0          6.0         34.0
# 195.235.248.46       46.0          6.0         34.0          6.0         34.0
# 195.53.217.43        36.0          6.0         34.0          6.0         34.0
# 212.170.33.198       45.0          6.0         34.0          6.0         34.0
# 195.235.248.60       45.0          6.0         34.0          6.0         34.0
# 195.235.248.190      41.0          6.0         34.0          6.0         34.0
#
#                    asn            prefix
# dip
# 195.53.217.36    30846   195.53.217.0/24
# 195.25.232.194    3215     195.25.0.0/16
# 57.74.24.130     51964      57.74.0.0/17
# 195.235.248.195  30846  195.235.248.0/24
# 212.170.33.244   30846   212.170.33.0/24
# 195.53.217.193   30846   195.53.217.0/24
# 195.235.248.34   30846  195.235.248.0/24
# 195.235.248.46   30846  195.235.248.0/24
# 195.53.217.43    30846   195.53.217.0/24
# 212.170.33.198   30846   212.170.33.0/24
# 195.235.248.60   30846  195.235.248.0/24
# 195.235.248.190  30846  195.235.248.0/24

# %% [markdown]
# Experimental ones?

# %%
sieve6all['expcookie']
# Out:
#                           conn_t0                     host    rank fwd_rst_t0  \
# dip
# 78.140.190.102               True             r7mediar.com    3023      False
# 163.172.40.207               True                meduza.io    7839      False
# 163.172.40.199               True                meduza.io    7838      False
# 5.199.134.80                 True                 kedem.ru   60041      False
# 89.108.106.190               True               fanat1k.ru   62387      False
# 203.162.59.2                 True            vieclam24h.vn   63067       True
# 144.76.82.156                True                samba.org   80131      False
# 2a01:4f8:192:486::443:2      True                samba.org   80132      False
# 185.22.172.173               True           animetosho.org  164005      False
# 2a00:1838:20:2::2c65:425e    True           animetosho.org  164006      False
# 61.147.80.168                True          ceve-market.org  254144      False
# 109.168.105.233              True                  stgy.it  313810       True
# 109.168.105.231              True                  stgy.it  313809       True
# 208.99.84.100                True  www.teamskeetimages.com  319306       True
# 208.99.84.102                True  www.teamskeetimages.com  319307       True
# 64.210.137.100               True  www.teamskeetimages.com  319312       True
# 208.99.84.104                True  www.teamskeetimages.com  319308       True
# 64.210.137.102               True  www.teamskeetimages.com  319313       True
# 128.199.73.182               True                imoney.ph  366299      False
# 52.10.34.69                  True       musicstorelive.com  369018      False
# 222.255.27.187               True            kenh14cdn.com  373858      False
# 222.255.27.184               True            kenh14cdn.com  373857      False
# 222.255.27.45                True            kenh14cdn.com  373859      False
# 140.211.167.135              True        enlightenment.org  377878       True
# 188.117.132.67               True               trzepak.pl  438061      False
# 222.255.27.101               True          vinaglue.edu.vn  451260      False
# 188.166.208.247              True                imoney.sg  633849      False
# 217.159.186.253              True                  rocs.ru  665364      False
# 52.24.209.126                True         pitbullaudio.com  674860      False
# 62.210.127.111               True     seashepherd-shop.com  777931       True
# 198.50.194.216               True         miconcinemas.com  838811      False
#
#                           rev_rst_t0 conn_t1 fwd_rst_t1 rev_rst_t1  \
# dip
# 78.140.190.102                 False    True      False      False
# 163.172.40.207                 False    True       True      False
# 163.172.40.199                 False    True       True      False
# 5.199.134.80                   False    True       True      False
# 89.108.106.190                 False    True       True      False
# 203.162.59.2                   False    True       True      False
# 144.76.82.156                  False    True       True      False
# 2a01:4f8:192:486::443:2        False    True       True      False
# %% [markdown]
# Double cookies?

# %%
sieve6all['twocookie']
# Out:
#                    conn_t0                              host    rank  \
# dip
# 195.53.217.36         True                         mapfre.es   53336
# 195.25.232.194        True                          macif.fr   62072
# 173.194.44.87         True  china-cdn88nmbwacdnln8hq8qwe.com   96387
# 195.216.236.10        True                      www.inbox.lt  119706
# 178.33.126.200        True                       tigerrr.com  138435
# 2001:41d0:b:6c8::1    True                       tigerrr.com  138436
# 57.74.24.130          True                           weg.net  144757
# 195.235.248.195       True               fundacionmapfre.org  158909
# 212.170.33.244        True                          verti.es  164578
# 195.53.217.193        True                        mapfre.com  180053
# 195.235.248.34        True            jubilacionypension.com  279894
# 195.235.248.46        True              mapfretecuidamos.com  288347
# 64.210.135.68         True           www.teamskeetimages.com  319309
# 64.210.135.72         True           www.teamskeetimages.com  319311
# 64.210.135.70         True           www.teamskeetimages.com  319310
# 66.254.122.104        True           www.teamskeetimages.com  319326
# 66.254.122.102        True           www.teamskeetimages.com  319325
# 66.254.122.100        True           www.teamskeetimages.com  319324
# 64.210.156.102        True           www.teamskeetimages.com  319319
# 64.210.156.100        True           www.teamskeetimages.com  319318
# 64.210.147.100        True           www.teamskeetimages.com  319315
# 64.210.147.104        True           www.teamskeetimages.com  319317
# 67.22.56.102          True           www.teamskeetimages.com  319328
# 67.22.56.104          True           www.teamskeetimages.com  319329
# 64.210.158.72         True           www.teamskeetimages.com  319323
# 67.22.56.100          True           www.teamskeetimages.com  319327
# 64.210.158.70         True           www.teamskeetimages.com  319322
# 64.210.158.68         True           www.teamskeetimages.com  319321
# 195.216.236.200       True                      www.inbox.eu  355262
# 195.53.217.43         True                        mapfre.net  609528
# 212.170.33.198        True               mapfre-warranty.com  713074
# 195.235.248.60        True               generacionyoung.com  769812
# 195.235.248.190       True                   mapfregrupo.com  884094
#
#                    fwd_rst_t0 rev_rst_t0 conn_t1 fwd_rst_t1 rev_rst_t1  \
# dip
# 195.53.217.36           False      False    True       True      False
# 195.25.232.194          False      False    True       True      False
# 173.194.44.87           False      False    True       True      False
# 195.216.236.10          False      False    True       True      False
# 178.33.126.200          False      False    True       True      False
# 2001:41d0:b:6c8::1      False      False    True       True      False
# 57.74.24.130            False      False    True       True      False
# 195.235.248.195         False      False    True       True      False
# 212.170.33.244          False      False    True       True      False
# 195.53.217.193          False       True    True       True      False
# 195.235.248.34          False      False    True       True      False
# 195.235.248.46          False       True    True       True      False
# 64.210.135.68            True      False    True       True      False
# 64.210.135.72            True      False    True       True      False
# 64.210.135.70            True      False    True       True      False
# 66.254.122.104           True      False    True       True      False
# 66.254.122.102           True      False    True       True      False
# 66.254.122.100           True      False    True       True      False
# 64.210.156.102           True      False    True       True      False
# 64.210.156.100           True      False    True       True      False
# 64.210.147.100           True      False    True       True      False
# 64.210.147.104           True      False    True       True      False
# 67.22.56.102             True      False    True       True      False
# 67.22.56.104             True      False    True       True      False
# 64.210.158.72            True      False    True       True      False
# 67.22.56.100             True      False    True       True      False
# 64.210.158.70            True      False    True       True      False
# 212.170.33.244             34.0          6.0         34.0  30846
# 195.53.217.193             34.0          6.0         34.0  30846
# 195.235.248.34             34.0          6.0         34.0  30846
# 195.235.248.46             34.0          6.0         34.0  30846
# 64.210.135.68              34.0          8.0         34.0  29789
# 64.210.135.72              34.0          8.0         34.0  29789
# 64.210.135.70              34.0          8.0         34.0  29789
# 66.254.122.104             34.0          8.0         34.0  29789
# 66.254.122.102             34.0          8.0         34.0  29789
# 66.254.122.100             34.0          8.0         34.0  29789
# 64.210.156.102             34.0          8.0         34.0  29789
# 64.210.156.100             34.0          8.0         34.0  29789
# 64.210.147.100             34.0          8.0         34.0  29789
# 64.210.147.104             34.0          8.0         34.0  29789
# 67.22.56.102               34.0          8.0         34.0  29789
# 67.22.56.104               34.0          8.0         34.0  29789
# 64.210.158.72              34.0          8.0         34.0  29789
# 67.22.56.100               34.0          8.0         34.0  29789
# 64.210.158.70              34.0          8.0         34.0  29789
# 64.210.158.68              34.0          8.0         34.0  29789
# 195.216.236.200            34.0          8.0         34.0  12993
# 195.53.217.43              34.0          6.0         34.0  30846
# 212.170.33.198             34.0          6.0         34.0  30846
# 195.235.248.60             34.0          6.0         34.0  30846
# 195.235.248.190            34.0          6.0         34.0  30846
#
#                               prefix
# dip
# 195.53.217.36        195.53.217.0/24
# 195.25.232.194         195.25.0.0/16
# 173.194.44.87        173.194.44.0/24
# 195.216.236.10      195.216.236.0/24
# 178.33.126.200         178.32.0.0/15
# 2001:41d0:b:6c8::1    2001:41d0::/32
# 57.74.24.130            57.74.0.0/17
# 195.235.248.195     195.235.248.0/24
# 212.170.33.244       212.170.33.0/24
# 195.53.217.193       195.53.217.0/24
# 195.235.248.34      195.235.248.0/24
# 195.235.248.46      195.235.248.0/24
# 64.210.135.68        64.210.128.0/19
# 64.210.135.72        64.210.128.0/19
# 64.210.135.70        64.210.128.0/19
# 66.254.122.104       66.254.122.0/24
# 66.254.122.102       66.254.122.0/24
# 66.254.122.100       66.254.122.0/24
# 64.210.156.102       64.210.128.0/19
# 64.210.156.100       64.210.128.0/19
# 64.210.147.100       64.210.128.0/19
# 64.210.147.104       64.210.128.0/19
# 67.22.56.102           67.22.56.0/24
# 67.22.56.104           67.22.56.0/24
# 64.210.158.72        64.210.128.0/19
# 67.22.56.100           67.22.56.0/24
# 64.210.158.70        64.210.128.0/19
# 64.210.158.68        64.210.128.0/19
# 195.216.236.200     195.216.236.0/24
# 195.53.217.43        195.53.217.0/24
# 212.170.33.198       212.170.33.0/24
# 195.235.248.60      195.235.248.0/24
# 195.235.248.190     195.235.248.0/24

# %% [markdown]
# ### Comparison with Andreas' results from June

# %%
andreas_df = pd.read_table("andreas_results.txt", delimiter="\s*\|\s*", engine="python")\
.set_index('ip')\
.drop("Unnamed: 0",axis=1)\
.drop("Unnamed: 13",axis=1)

# %%
len(andreas_df)
# Out:
# 362

# %%
len(andreas_df[andreas_df['google'] == 1])
# Out:
# 304

# %%
# Domain set intersection
jan_tfoset = set(sieve6all['cookie']['host'].unique())
jun_tfoset = set(andreas_df['host'].unique())
jan_allset = set(resolute_jdf['host'].unique())

# %%
jun_tfoset
# Out:
# {'abema.tv',
#  'allabout-japan.com',
#  'anonanalytics.com',
#  'ato.mx',
#  'd35classicapp.com',
#  'digitalworldads.com',
#  'dudeplaygames.com',
#  'gamez4tops.com',
#  'mobilepinbox.com',
#  'notifuse.com',
#  'number1hazard.com',
#  'shipment.co',
#  'shop3stockoff.com',
#  'takusuta.com',
#  'ussto.com',
#  'w20sweeplnd.com',
#  'widevine.com',
#  'www.2016cbseresultsnic.in',
#  'www.20speed.co',
#  'www.2ality.com',
#  'www.ad-2.me',
#  'www.ad4screen.com',
#  'www.adbuddiz.com',
#  'www.addressreport.com',
#  'www.admob.com',
#  'www.adyoulike.com',
#  'www.aladdin.ie',
#  'www.almadia.pl',
#  'www.alvexo.com',
#  'www.ambev.com.br',
#  'www.aporta.org.mx',
#  'www.arbor.io',
#  'www.arrow-arrow.com',
#  'www.auntbertha.com',
#  'www.bablic.com',
#  'www.balagannna.com',
#  'www.balatarin.com',
#  'www.battlefieldbr.com',
#  'www.bbfdirect.com',
#  'www.beatstage.com',
#  'www.beautyscenery.com',
#  'www.blockly-games.appspot.com',
#  'www.blogspot.com',
#  'www.blogspot.com.cy',
#  'www.blossom.io',
#  'www.boxc.com',
#  'www.bq.com',
#  'www.bqreaders.com',
#  'www.buysellpassport.com',
#  'www.careeravenue.com',
#  'www.cart-checkout.com',
#  'www.censys.io',
#  'www.chromium.org',
#  'www.cincymls.net',
#  'www.cmsantagostino.it',
#  'www.cocina-casera.com',
#  'www.cocycles.com',
#  'www.codeskulptor.org',
#  'www.conjur.com.br',
#  'www.constituteproject.org',
#  'www.corotos.com.do',
#  'www.crozdesk.com',
#  'www.cubeslam.com',
#  'www.dariknews.bg',
#  'www.dartlang.org',
#  'www.dashub.com',
#  'www.dcard.tw',
#  'www.dereferer.me',
#  'www.dersteknik.com',
#  'www.dialpad.com',
#  'www.disneytickets.co.uk',
#  'www.docketalarm.com',
#  'www.dopr.net',
#  'www.dot.cf',
#  'www.drrr.com',
#  'www.ebl.com.bd',
#  'www.edgbaston.com',
#  'www.ehost.com',
#  'www.elsoldemexico.com.mx',
#  'www.episodeinteractive.com',
#  'www.epochtimes.com',
#  'www.essayassay.com',
#  'www.etsyonsale.com',
#  'www.eventshigh.com',
#  'www.evite.com',
#  'www.exchange4media.com',
#  'www.express.com.pk',
#  'www.fancyhands.com',
#  'www.fanpagekarma.com',
#  'www.fantia.jp',
#  'www.farmigo.com',
#  'www.fibrenoire.ca',
#  'www.filewatcher.com',
#  'www.focus.ua',
#  'www.food.co.il',
#  'www.formy-i-blanki.ru',
#  'www.franchisehelp.com',
#  'www.freenom.com',
#  'www.freeseoblog.ru',
#  'www.frip.com',
#  'www.fromtheboxoffice.com',
#  'www.fullstory.com',
#  'www.fundacionmapfre.org',
#  'www.gdog168.com',
#  'www.gemr.com',
#  'www.gene-media.com',
#  'www.getyarn.io',
#  'www.globaltechpost.com',
#  'www.gmail.com',
#  'www.go1buy1.com',
#  'www.google-melange.com',
#  'www.google.cn',
#  'www.google.co.in',
#  'www.google.com',
#  'www.googleadservices.com',
#  'www.googleapis.com',
#  'www.googleblog.com',
#  'www.googlecode.com',
#  'www.googlegoro.com',
#  'www.googlegroups.com',
#  'www.googleplex.com',
#  'www.googlesciencefair.com',
#  'www.googletagmanager.com',
#  'www.googletagservices.com',
#  'www.googleusercontent.com',
#  'www.gorgias.io',
#  'www.gqueues.com',
#  'www.grandpad.net',
#  'www.grifo210.com',
#  'www.gudog.com',
#  'www.haychoigame.com',
#  'www.hebban.nl',
#  'www.hipotels.com',
#  'www.hitbiju.ru',
#  'www.hostclear.com',
#  'www.hudora.de',
#  'www.huge-options.com',
#  'www.humblebundle.com',
#  'www.hundredrooms.com',
#  'www.iaa.gov.il',
#  'www.ianlewis.org',
#  'www.ideahost.com',
#  'www.ifoodie.tw',
#  'www.ilbuongiorno.it',
#  'www.imoney.ph',
#  'www.inbox.eu',
#  'www.inbox.lt',
#  'www.incognitovpn.com',
#  'www.ingress.com',
#  'www.instantdomainsearch.com',
#  'www.instapage.com',
#  'www.itviet360.com',
#  'www.jeeadv.ac.in',
#  'www.jjgames.com',
#  'www.joblift.de',
#  'www.jobright.com',
#  'www.johnnys-net.jp',
#  'www.jubilacionypension.com',
#  'www.junyiacademy.org',
#  'www.justapinch.com',
#  'www.justcloud.com',
#  'www.juventus.com',
#  'www.kastatic.org',
#  'www.keepy.me',
#  'www.kesuskim.com',
#  'www.keyhole.com',
#  'www.keyingredient.com',
#  'www.khanacademy.org',
#  'www.kindara.com',
#  'www.kinsta.com',
#  'www.kjvvv.kr',
#  'www.koukni.cz',
#  'www.kreativeideer.com',
#  'www.kubity.com',
#  'www.kumpulansoaltest.blogspot.co.id',
#  'www.kyivpost.com',
#  'www.lenstag.com',
#  'www.leonax.net',
#  'www.lezhin.com',
#  'www.lidota.vn',
#  'www.lierac.fr',
#  'www.lindaikejisblog.com',
#  'www.livehouse.in',
#  'www.lmfdb.org',
#  'www.longine.jp',
#  'www.looklet.com',
#  'www.loudr.fm',
#  'www.lovemondays.com.br',
#  'www.macif.fr',
#  'www.magenmagic.com',
#  'www.mail.ee',
#  'www.mantan-web.jp',
#  'www.mapadaprova.com.br',
#  'www.mapfre.com',
#  'www.mapfre.es',
#  'www.mapfre.net',
#  'www.mapfretecuidamos.com',
#  'www.mapio.net',
#  'www.matchclub.dk',
#  'www.matterhackers.com',
#  'www.maxiforex.ru',
#  'www.mdais.org',
#  'www.media.wix.com',
#  'www.meethue.com',
#  'www.metacdn.com',
#  'www.mibqyyo.com',
#  'www.micomercialtoddy.com',
#  'www.miraie.me',
#  'www.mizancudito.com',
#  'www.my.ga',
#  'www.mypcbackup.com',
#  'www.mystudentdashboard.com',
#  'www.mysupermarket.co.il',
#  'www.mysupermarket.co.uk',
#  'www.netotrade.com',
#  'www.nextivafax.com',
#  'www.non.li',
#  'www.noracomunicacao.com.br',
#  'www.odrive.com',
#  'www.offersupply.com',
#  'www.okthere.com',
#  'www.omegaoptions.com',
#  'www.oulala.com',
#  'www.padpadblog.com',
#  'www.pancake.vn',
#  'www.pdfconverterhq.appspot.com',
#  'www.pexe.so',
#  'www.phantomjscloud.com',
#  'www.photographyisnotacrime.com',
#  'www.phyto.fr',
#  'www.pigeonsandplanes.com',
#  'www.pins.fi',
#  'www.pinsforme.com',
#  'www.pixoto.com',
#  'www.point.ml',
#  'www.porch.com',
#  'www.porijazz.fi',
#  'www.porterfinance.com',
#  'www.prepladder.com',
#  'www.profissa.net',
#  'www.projectnoah.org',
#  'www.prosent.no',
#  'www.ptichki.club',
#  'www.pulse.me',
#  'www.radioradicale.it',
#  'www.raterhub.com',
#  'www.realmassive.com',
#  'www.recaptcha.net',
#  'www.regiocollege.nl',
#  'www.rgames.jp',
#  'www.rinkak.com',
#  'www.rogerhub.com',
#  'www.roomle.com',
#  'www.runechat.com',
#  'www.s-e-s.co',
#  'www.saferweb.com',
#  'www.santaclarasystems.com',
#  'www.sbrick.com',
#  'www.sende.rs',
#  'www.sener.es',
#  'www.servingclks.com',
#  'www.shopifiedapp.com',
#  'www.showpad.com',
#  'www.siersaglik.com',
#  'www.signal.bg',
#  'www.siteblog.com',
#  'www.sitenizolsun.com',
#  'www.slownet.ne.jp',
#  'www.small-improvements.com',
#  'www.smartamp.com',
#  'www.smarterweblife.com',
#  'www.snapengage.com',
#  'www.social-lunch.jp',
#  'www.sofiaapartament.com',
#  'www.sohomod.com',
#  'www.solestruck.com',
#  'www.sonicdrivein.com',
#  'www.spacial.jp',
#  'www.staatsloterij.nl',
#  'www.stickermanager.com',
#  'www.sublinet.com',
#  'www.submenow.com',
#  'www.swap.com',
#  'www.sweetprotection.com',
#  'www.symphonytools.com',
#  'www.tadpoles.com',
#  'www.talentclue.com',
#  'www.teamskeetimages.com',
#  'www.teleport.org',
#  'www.terminals.io',
#  'www.the-alba.com',
#  'www.thedailyaztec.com',
#  'www.thelayoff.com',
#  'www.thinktheology.co.uk',
#  'www.thinkwave.com',
#  'www.tiebow-tie.com',
#  'www.tigerrr.com',
#  'www.tiltbrush.com',
#  'www.tinytap.it',
#  'www.totalvpn.com',
#  'www.toyga.com',
#  'www.traderoo.com.au',
#  'www.tropicaltrade.com',
#  'www.truesocks.net',
#  'www.twentyfourseven.co.il',
#  'www.twpro.jp',
#  'www.twreporter.org',
#  'www.uberconference.com',
#  'www.unionbank.co.il',
#  'www.uprisingtech.com',
#  'www.vertalen.nu',
#  'www.verti.es',
#  'www.vetconnectplus.com',
#  'www.vetconnectplus.fr',
#  'www.videopixie.com',
#  'www.virustotal.com',
#  'www.waze.com',
#  'www.webinmerkezi.com',
#  'www.weblogzwolle.nl',
#  'www.wedmegood.com',
#  'www.wemood.co',
#  'www.weotta.com',
#  'www.whoscall.com',
#  'www.withgoogle.com',
#  'www.wondermall.com',
#  'www.workana.com',
#  'www.x4b.net',
#  'www.xcams.de',
#  'www.yenitrt.com',
#  'www.youtube.com',
#  'www.zeetings.com',
#  'www.zipcloud.com',
#  'www.zjogos.com.br'}
